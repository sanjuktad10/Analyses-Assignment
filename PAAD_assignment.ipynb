# %%
import cmapPy     #importing the package

# %%
from cmapPy.pandasGEXpress.parse import parse   #importing the package

# %%
cmapPy.pandasGEXpress.parse.parse(file_path="/home/sanjuta/Desktop/Elucidata/data_analyst_intern-20200203T073632Z-001/data_analyst_intern/PAAD.gct", convert_neg_666=True, rid=None, cid=None, ridx=None, cidx=None, row_meta_only=False, col_meta_only=True, make_multiindex=False)
#after parsing the data creating the data frame from GCT file
# Out:
# chd                      participant_id          sample_type  mRNAseq_cluster  \
# cid
# aab1-Primary solid Tumor           aab1  Primary solid Tumor              1.0
# aab4-Primary solid Tumor           aab4  Primary solid Tumor              2.0
# aab6-Primary solid Tumor           aab6  Primary solid Tumor              3.0
# aab8-Primary solid Tumor           aab8  Primary solid Tumor              1.0
# aab9-Primary solid Tumor           aab9  Primary solid Tumor              4.0
# aaba-Primary solid Tumor           aaba  Primary solid Tumor              3.0
# aabe-Primary solid Tumor           aabe  Primary solid Tumor              3.0
# aabf-Primary solid Tumor           aabf  Primary solid Tumor              2.0
# aabh-Primary solid Tumor           aabh  Primary solid Tumor              2.0
# aabi-Primary solid Tumor           aabi  Primary solid Tumor              3.0
# aabk-Primary solid Tumor           aabk  Primary solid Tumor              2.0
# ...

# %%
dataset=cmapPy.pandasGEXpress.parse.parse(file_path="/home/sanjuta/Desktop/Elucidata/data_analyst_intern-20200203T073632Z-001/data_analyst_intern/PAAD.gct", convert_neg_666=True, rid=None, cid=None, ridx=None, cidx=None, row_meta_only=False, col_meta_only=True, make_multiindex=False)

# %%
dataset.shape   #checking the dimension of data
# Out:
# (183, 124)

# %%
dataset.columns   #checking the columns
# Out:
# Index([u'participant_id', u'sample_type', u'mRNAseq_cluster',
#        u'bcr_patient_barcode', u'bcr_patient_uuid', u'vital_status',
#        u'days_to_death', u'days_to_last_followup', u'additional_studies',
#        u'adenocarcinoma_invasion',
#        ...
#        u'tobacco_smoking_history', u'total_dose', u'total_dose_units',
#        u'tumor_tissue_site', u'tumor_type', u'withdrawn',
#        u'year_of_dcc_upload', u'year_of_form_completion',
#        u'year_of_initial_pathologic_diagnosis',
#        u'year_of_tobacco_smoking_onset'],
#       dtype='object', name=u'chd', length=124)

# %%
dataset["histological_type_other"]
# Out:
# cid
# aab1-Primary solid Tumor                              invasive adenocarcinoma
# aab4-Primary solid Tumor                        invasive, well-differentiated
# aab6-Primary solid Tumor                                                  NaN
# aab8-Primary solid Tumor                                                  NaN
# aab9-Primary solid Tumor                                                  NaN
# aaba-Primary solid Tumor                                                  NaN
# aabe-Primary solid Tumor                                                  NaN
# aabf-Primary solid Tumor                                                  NaN
# aabh-Primary solid Tumor                              invasive adenocarcinoma
# aabi-Primary solid Tumor                 poorly differentiated adenocarcinoma
# aabk-Primary solid Tumor                                                  NaN
# aabo-Primary solid Tumor                                                  NaN
# ...

# %%
dataset[dataset['histological_type_other'].str.contains("neuroendocrine")==False]
# Out:
# chd                      participant_id          sample_type  mRNAseq_cluster  \
# cid
# aab1-Primary solid Tumor           aab1  Primary solid Tumor              1.0
# aab4-Primary solid Tumor           aab4  Primary solid Tumor              2.0
# aabh-Primary solid Tumor           aabh  Primary solid Tumor              2.0
# aabi-Primary solid Tumor           aabi  Primary solid Tumor              3.0
# 6879-Primary solid Tumor           6879  Primary solid Tumor              1.0
# a45n-Solid Tissue Normal           a45n  Solid Tissue Normal              NaN
# a45n-Primary solid Tumor           a45n  Primary solid Tumor              2.0
# a6c1-Primary solid Tumor           a6c1  Primary solid Tumor              1.0
# a7op-Primary solid Tumor           a7op  Primary solid Tumor              1.0
# 7289-Primary solid Tumor           7289  Primary solid Tumor              1.0
# 8519-Primary solid Tumor           8519  Primary solid Tumor              2.0
# ...

# %%
dataset2= dataset[dataset['histological_type_other'].str.contains("neuroendocrine")==False]    #filtering the data

# %%
dataset2["histological_type_other"]     #filtered data
# Out:
# cid
# aab1-Primary solid Tumor                            invasive adenocarcinoma
# aab4-Primary solid Tumor                      invasive, well-differentiated
# aabh-Primary solid Tumor                            invasive adenocarcinoma
# aabi-Primary solid Tumor               poorly differentiated adenocarcinoma
# 6879-Primary solid Tumor                                adenocarcinoma, nos
# a45n-Solid Tissue Normal    poorly differentiated pancreatic adenocarcinoma
# a45n-Primary solid Tumor    poorly differentiated pancreatic adenocarcinoma
# a6c1-Primary solid Tumor                                      not specified
# a7op-Primary solid Tumor               intraductal tubulopapillary neoplasm
# 7289-Primary solid Tumor                                adenocarcinoma, nos
# 8519-Primary solid Tumor                                adenocarcinoma, nos
# a4bk-Primary solid Tumor                                adenocarcinoma, nos
# ...
